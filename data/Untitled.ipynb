# %%
import pandas as pd

# %%
df = pd.read_csv('regional_to_muni.csv.gz')

df
# Out:
#       geocodigo                uf  id_regional          regional  \
# 0       1100189          Rondônia        11002              Cafe
# 1       1100296          Rondônia        11005      Zona Da Mata
# 2       1101476          Rondônia        11002              Cafe
# 3       1301902          Amazonas        13004    Medio Amazonas
# 4       1302702          Amazonas        13003       Rio Madeira
# ...         ...               ...          ...               ...
# 5565    5222302             Goiás        52018   Sao Patricio Ii
# 5566    5222005             Goiás        52002        Centro Sul
# 5567    5222054             Goiás        52002        Centro Sul
# 5568    5221908             Goiás        52002        Centro Sul
# 5569    5300108  Distrito Federal        53001  Distrito Federal
#
#       macroregional_id     macroregional
# 0                 1101       II – CACOAL
# 1                 1101       II – CACOAL
# 2                 1101       II – CACOAL
# ...

# %%
df.loc[df.geocodigo == 3549805.]
# Out:
#       geocodigo         uf  id_regional               regional  \
# 4281    3549805  São Paulo        35155  Sao Jose Do Rio Preto
#
#       macroregional_id macroregional
# 4281              3531        RRAS12
